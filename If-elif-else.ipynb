# %%
a=int(input("Enter a number: "))
b=int(input("Enter a number: "))
if a>b:
  print(a,":a is greater than b")
else:
  print(b,":b is greater than a")
# Out:
# Enter a number: 34
# Enter a number: 76
# 76 :b is greater than a

# %%
a=int(input("Enter a number: "))
b=int(input("Enter a number: "))
c=int(input("Enter a number: "))
if a>b:
  if a>c:
    print(a, ": a is greater than b and c")
  else:
    print(c, "c is greater than b and a")
if b>c:
  print(b,": b is greater than a and c")
else:
  print(c,": c is greater than b and a")
# Out:
# Enter a number: 23
# Enter a number: 56
# Enter a number: 55
# 56 : b is greater than a and c

# %%
num=int(input("Enter a number: "))
if num>0:
  print("The given number is positive in nature")
elif num<0:
  print("The given nnumber is negative in nature")
else:
  print("The given number is zero")
# Out:
# Enter a number: 34
# The given number is positive in nature

# %%
num=int(input("Enter a number: "))
if num%5==0 or num%11==0:
  print("The number given can be divided by either 5 or 11")
else:
  print("The number given not divided by either 11 or 5")
# Out:
# Enter a number: 23
# The number given not divided by either 11 or 5

# %%
num=int(input("Enter a number: "))
if num%2==0:
  print("Even Number")
elif num%2!=0:
  print("Odd Number")
else:
  print("Please enter again")
# Out:
# Enter a number: 67
# Odd Number

# %%
year=int(input("Enter the number of the year: "))
if year%4==0:
  print("The metioned year is a leap year")
elif year%100==0 and year%400==0:
  print("The metioned year is a centurian leap year")
else:
  print("Its not a leap year")
# Out:
# Enter the number of the year: 1800
# The metioned year is a leap year

# %%
cha=input("Enter any character: ")
if ((cha>= "a") and (cha<="z")):
  print("Alphabet")
elif((cha>="A" and cha<="Z")):
  print("Alphabet")
elif ((cha>="0") and cha<="9"):
  print("Digit")
else:
  print("The given character is a speacial character")
# Out:
# Enter any character: #
# The given character is a speacial character
