# %%
print("Printing all the Even Numbers:")
num=0
while num<20:
  print(num)
  num+=2
print("Printing all the Odd Numbers:")
num=1
while num<20:
  print (num)
  num+=2
print("Printing all the Natural Numbers:")
num=1
while num<10:
 print(num)
 num+=1
num=0
print("Printing all the Whole Numbers:")
while num<10:
  print(num)
  num+=1

# %%
num=0
while num<10:
  print(num,num**2)
  num+=1


for i in range(10):
  print(i,i**2)

# %%
num=10
while num<=300:
  print(num, end =", ")
  num+=10

for i in range(10,300,10):
  print(i,end=" ")

# %%
num=105
while num>=7:
  print(num, end=" ")
  num-=7

# %%
num=10
while num>=1:
  print(num, end= " ")
  num-=1

# %%
num=1
n=int(input())
sum=0
while num<=n:
  sum+=num
  num+=1
print(sum)
# Out:
# 55

# %%
num=0
sum=0
while num<20:
   sum+=num
   num+=2
print(sum)

# %%
num=int(input("Enter the number you want table of: "))
table=1
while table<=10:
  print(num*table)
  table+=1

# %%
a=int(input("Enter a number: "))
b=int(input("Enter a number: "))
c=a+1
while c<b:
  if c%2==0:
    print(c,"Even")
  else:
    print(c,"Odd")
  c+=1
# Out:
# Enter a number: 2
# Enter a number: 9
# 3 Odd
# 4 Even
# 5 Odd
# 6 Even
# 7 Odd
# 8 Even

# %%
num=int(input("Enter a number: "))
while num%2!=0 and num%3!=0:
  print("Yes, it is a prime number")
  break
else:
  print("No, it is not a prime number")

# %%
#Write a program to find the product of the digits of a number accepted from the user
# # num=int(input("Enter a number: "))
# # n=num
# # product=1;
# # while n!=0:
# #   product=product*(n%10)
# #   n=int(num//10)
# # print("The product of all the digits of the number:" ,n, "is=", product)
  

# num = input("Enter any number : ")
# f = len(num)
# i=1
#  num:
#    f = f * int(i)
# print("Product of the digits is  : ", f)
# num=input("Enter any number: ")
# l=list(num)
# sum=0
# i=[0]
# a=l[0: ]
# while i<[-1]:
#   i+=1 
# print(a)
# a=list(map(int,a))
# print(a)
#   sum+=a 
#   print(sum)


# Write a program to find the sum of the digits of a number accepted from the user
num=int(input("Enter any number: "))
n=str(num)
sum=0
i=0
while i<len(n):
  sum+=int(n[i])
  i+=1
print(sum)

# %%
#Write a program to reverse the number accepted by the user
num=input("Enter a number: ")
print("The reverse number is: ",num[::-1])

# a=7943
# reverse=0
# while a<=0:hh
#  reverse=a%10
#  reverse=reverse+(reverse*10)
#  reverse=reverse//10
# print(reverse)

# a=1234
# Out:
# Enter a number: 12345
# The reverse number is:  54321

# %%
# #Write a program to display the number names of the digits of if the number is 231 then output should be
# Two a number entered by user, for example Three One

# %%
#Write a program to print the Fibonacci series till n terms (Accept n from user)
num=int(input("Enter the length of the series: "))
i=1
sum=0
while i<=num:
  sum=+i
  print(sum, end=" ")
  i+=1
# Out:
# Enter the length of the series: 4
# 1 2 3 4

# %%
#Write a program to print the factorial of a number accepted by the user
num=int(input("Please enter your number: "))
pro=1
i=1
while i<=num:
  pro*=i
  i+=1
print(pro)
# Out:
# Please enter your number: 2
# 2

# %%
# #Write a program to check whether a number is Armstrong or not. (Armstrong number is a number that is
# equal to the sum of cubes of its digits, for example : 153 = 1^3 + 5^3 + 3^3.)

# %%
#. Write a program to convert binary to decimal
num=int(input("Enter any decimal number: "))
i=0
bin=0
while i<=num:
  bin=num%2
  if bin==0:
   print(bin)
  if bin==1:
   print(bin)
  i+=0

# %%
# Write a program to add first n terms of the following series using a while loop :
# 1/1! + 1/2! + 1/3! + …….. + 1/n!

# %%
# Write a program to check whether a number is palindrome or not
s1=input("Enter any number: ")
s2=s1[::-1]
print(s2)
if s1==s2:
  print("Yes it is a palindrome")
else:
  print("No, it is not a palindrome")

# %%
# Write a program to accept 10 numbers from the user and display it’s average
i=1
sum=0
while i<=10:
  num=int(input("Enter any number: "))
  sum+=num
  i+=1
print("The sum of the guven numbers are: ", sum)
avg=sum/10
print("The average of the guven numbers is: ", avg)

# %%
# Write a program to accept 10 numbers from the user and display the largest & smallest number
i=1
while i<=10:
  num=int(input("Enter any number: "))
  if i<num:

# %%
# Write a program to display sum of odd numbers and even numbers separately that fall between two
# numbers accepted from the user.(including both numbers) 100 and 500
i=

# %%
#Write a program to find the sum of following series:
#S = 1 + 4 – 9 + 16 – 25 + 36 – … … n terms
num=int(input("Enter the no. of terms you want to add: "))
i=1
while i<=num:
  if i==1:
    print(i, end=" ")
  elif i%2!=0:
    print(-i**2, end=" ")
  else:
    print("+",i**2, end=" ")
  i+=1
# Out:
# Enter the no. of terms you want to add: 8
# 1 + 4 -9 + 16 -25 + 36 -49 + 64

# %%
i=1
while i<=5:
  j=1
  while j<=i:
    print(i+j, end=" ")
    j+=1
  i+=1
  print()
# Out:
# 2
# 3 4
# 4 5 6
# 5 6 7 8
# 6 7 8 9 10

# %%
i=1
while i<=5:
  j=1
  while j<=i:
    if j%2==0:
      print(j+i, end=" ")
    else:
      print("*" * i, end=" ")
    j+=1
  i+=1
  print()
# Out:
# *
# ** 4
# *** 5 ***
# **** 6 **** 8
# ***** 7 ***** 9 *****

# %%
n=5
for i in range(n):
  for j in range(i):
    if j%2==0:
      print(i, end=" ")
    else:
      print("*" *j,end=" ")
  print()
# Out:
# 1
# 2 *
# 3 * 3
# 4 * 4 ***

# %%
n=int(input("Enter: "))
i=1

# %%
#Find positional prime numbers by using while loop.
num=int(input("Enter a number: "))
prime=[]
while num!=100:
  i=1
  while i<=10:
    if num%i==0:
     pass
    else:
      prime.append(i)
    i = i+1
  print(prime)
  break

# %%
num=int(input("Enter a number: "))
prime=[]
while num!=100:
  i=2
  while i<=10:
    if num%i==0:
      print("Not Prime")
    else:
      print("Prime")
      break
    i+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# Not Prime
# Prime
# Not Prime
# ...

# %%
n=int(input("Enter a number: "))
i=1
sum=0
product=1
ans=0
while i<=n:
  j=1
  while j<=i:
    product*=j
    j+=1
  sum=sum+1/product
  i+=1
print(sum)
# Out:
# Enter a number: 3
# 1.5833333333333333

# %%
#Doubt, correct logic, wrong code
n=int(input("Enter a number: "))
i=0
while i<=n:
  j=1
  while j<=i:
    print("*",end=" ")
  k=0
  while k<=i:
    print(" ",end=" ")
  print()

# %%
n=int(input("Enter a number: "))
i=1
while n!=1:
  if n%2!=0:
    n=(n*3+1)
  else:
    n=n/2
  i+=1
print(i)
# Out:
# Enter a number: 12
# 1

# %%
n=int(input("Enter a number: "))
# i=1
# if n%3==0:
#    while n!=1:
#     if n%2==0:
#       n=(n*2)+1
#     else:
#       n=n%3
# else:
#     print("No, this number this number cannot go towards 1")


flag=0
while n!=1:
  if n%2!=0:
    n=(n*2+1)
  if n%3==0:
    n=n/3
  else:
    flag=1
    break

# %%
import math
n=int(input("Enter: "))
print(math.log(n,10))
# Out:
# Enter: 1234
# 3.091315159697223

# %%
n=int(input("Enter: "))
i=0
# while n!=1:
#   if n%2==0:
#     n=n/2
#     i+=1
#   else:
#     break
# print(n,i)


while 2**i<n:
  i+=1
print(i)
# Out:
# Enter: 20
# 5

# %%
n=int(input("Enter: "))
m=int(input("Enter: "))

if n>m:
  a=n
else:
  a=m
while True:
  if a%n==0 and a%m==0:
    print(a, "is the LCM")
    break
  a+=1
LCM=a

HCF=(n*m)/LCM
print(HCF, "is the HCF")

# %%
a=int(input("Enter: "))
b=int(input("Enter: "))
c=min(n,m)
result=0
i=1
while i<=c:
  if a%i==0 and b%i==0:
    result=i
  i+=1
print(result,"is the HCF")

LCM=(a*b)/result
print(LCM,"is the LCM")

# %%
a=1
d=3
n=7

s=n/2(2*a(n-1)*d)
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b0c180c6bbed> in <module>()
#       3 n=7
#       4
# ----> 5 s=n/2(2*a(n-1)*d)
#       6 print(s)
#
# TypeError: 'int' object is not callable
